# %%
from pathlib import Path

from pachner_traversal.data_io import Dataset, convert_to_hdf5
from pachner_traversal.utils import data_path

# %%
files_to_convert = [
    'spheres_5tet.txt',
    'spheres_6tet.txt',
    'spheres_7tet.txt',
    'spheres_8tet.txt',
    'spheres_9tet.txt',
    'spheres_10tet.txt',
    'spheres_11tet.txt',
    'spheres_12tet.txt',
]

for file in files_to_convert:
    src_path = data_path / 'input_data' / 'raw' / file
    dest_path = data_path / 'input_data' / 'processed' / file.replace('.txt', '.hdf5')

    convert_to_hdf5(src_path, dest_path)
